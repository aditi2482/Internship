# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_excel(r"C:\Users\lenovo\Downloads\customer_retention.xlsx")

# %%
df.head()
# Out:
#   1Gender of respondent          Age           City  \
# 0                  Male  31-40 years          Delhi
# 1                Female  21-30 years          Delhi
# 2                Female  21-30 years  Greater Noida
# 3                  Male  21-30 years        Karnal
# 4                Female  21-30 years     Bangalore
#
#    4 What is the Pin Code of where you shop online from?       Duration  \
# 0                                             110009      Above 4 years
# 1                                             110030      Above 4 years
# 2                                             201308          3-4 years
# 3                                             132001          3-4 years
# 4                                             530068          2-3 years
#
#        Purchase Times  \
# 0         31-40 times
# 1  41 times and above
# 2  41 times and above
# 3  Less than 10 times
# 4         11-20 times
#
#   7 How do you access the internet while shopping on-line?  \
# ...

# %%
pd.set_option('display.max_columns',500)

# %%
df.nunique()
# Out:
# 1Gender of respondent                                        2
# Age                                                          5
# City                                                        11
# 4 What is the Pin Code of where you shop online from?       39
# Duration                                                     5
#                                                             ..
# Longer delivery period                                       6
# Change in website/Application design                         7
# Frequent disruption when moving from one page to another     8
# Efficient Website                                            8
# Recommendation                                               8
# Length: 71, dtype: int64

# %%
df['City'].unique()
# Out:
# array(['Delhi', 'Greater Noida', 'Karnal ', 'Bangalore ', 'Noida',
#        'Solan', 'Moradabad', 'Gurgaon ', 'Merrut', 'Ghaziabad',
#        'Bulandshahr'], dtype=object)

# %%
df['Purchase Times'].unique()
# Out:
# array(['31-40 times', '41 times and above', 'Less than 10 times',
#        '11-20 times', '21-30 times', '42 times and above'], dtype=object)

# %%
df['Convenience'].unique()
# Out:
# array(['Dis-agree (2)', 'Strongly agree (5)', 'indifferent (3)',
#        'Agree (4)'], dtype=object)

# %% [markdown]
# # Checking the null values in the dataset

# %%
df.columns
# Out:
# Index(['1Gender of respondent', 'Age', 'City',
#        '4 What is the Pin Code of where you shop online from?', 'Duration',
#        'Purchase Times',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
#        '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ',
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# 1Gender of respondent                                       object
# Age                                                         object
# City                                                        object
# 4 What is the Pin Code of where you shop online from?        int64
# Duration                                                    object
#                                                              ...
# Longer delivery period                                      object
# Change in website/Application design                        object
# Frequent disruption when moving from one page to another    object
# Efficient Website                                           object
# Recommendation                                              object
# Length: 71, dtype: object

# %% [markdown]
# # Visualization of Data

# %%
ax=sns.countplot(x="Best Deal",data=df)
df['Best Deal'].value_counts()
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: Best Deal, dtype: int64

# %%
ax=sns.countplot(x="roles",data=df)
df['roles'].value_counts()
# Out:
# Agree (4)                88
# indifferent (3)          88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: roles, dtype: int64

# %%
ax=sns.countplot(x="Product Offerings",data=df)
df['Product Offerings'].value_counts()
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: Product Offerings, dtype: int64

# %%
ax=sns.countplot(x="Monetary savings",data=df)
df['Monetary savings'].value_counts()
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: Monetary savings, dtype: int64

# %%
ax=sns.countplot(x="product information",data=df)
df['product information'].value_counts()
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: product information, dtype: int64

# %%
ax=sns.countplot(x="Adventure",data=df)
df['Adventure'].value_counts()
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: Adventure, dtype: int64

# %%
ax=sns.countplot(x="social status",data=df)
df['social status'].value_counts()
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: social status, dtype: int64

# %%
ax=sns.countplot(x="Convenience",data=df)
df['Convenience'].value_counts()
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: Convenience, dtype: int64

# %%
ax=sns.countplot(x="1Gender of respondent",data=df)
print(df["1Gender of respondent"].value_counts())
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
ax=sns.countplot(x="City",data=df)
df['City'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: City, dtype: int64

# %%
ax=sns.countplot(x="Age",data=df)
df['Age'].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: Age, dtype: int64

# %%
ax=sns.countplot(x="Duration",data=df)
df['Duration'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: Duration, dtype: int64

# %%
ax=sns.countplot(x="Reason for abandonment",data=df)
df['Reason for abandonment'].value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        53
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# x                                 1
# Name: Reason for abandonment, dtype: int64

# %%
ax=sns.countplot(x="Perceived Trustworthiness",data=df)
df['Perceived Trustworthiness'].value_counts()
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64

# %%
ax=sns.countplot(x="Efficient Website",data=df)
df['Efficient Website'].value_counts()
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Efficient Website, dtype: int64

# %%
ax=sns.countplot(x="Recommendation",data=df)
df['Recommendation'].value_counts()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Recommendation, dtype: int64

# %% [markdown]
# # Encoding of Dataframe

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#      1Gender of respondent  Age  City  \
# 0                      1.0  1.0   2.0
# 1                      0.0  0.0   2.0
# 2                      0.0  0.0   4.0
# 3                      1.0  0.0   6.0
# 4                      0.0  0.0   0.0
# ..                     ...  ...   ...
# 264                    0.0  0.0  10.0
# 265                    0.0  1.0   3.0
# 266                    0.0  2.0   0.0
# 267                    0.0  4.0  10.0
# 268                    0.0  2.0   3.0
#
#      4 What is the Pin Code of where you shop online from?  Duration  \
# 0                                               110009           3.0
# 1                                               110030           3.0
# 2                                               201308           2.0
# 3                                               132001           2.0
# 4                                               530068           1.0
# ..                                                 ...           ...
# ...

# %%
df.describe()
# Out:
#        1Gender of respondent         Age        City  \
# count             269.000000  269.000000  269.000000
# mean                0.327138    1.330855    4.494424
# std                 0.470042    1.183774    3.187687
# min                 0.000000    0.000000    0.000000
# 25%                 0.000000    0.000000    2.000000
# 50%                 0.000000    1.000000    4.000000
# 75%                 1.000000    2.000000    7.000000
# max                 1.000000    4.000000   10.000000
#
#        4 What is the Pin Code of where you shop online from?    Duration  \
# count                                         269.000000      269.000000
# mean                                       220465.747212        2.323420
# std                                        140524.341051        1.176357
# min                                        110008.000000        0.000000
# 25%                                        122018.000000        1.000000
# ...

# %% [markdown]
# # Label Encoding

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.heatmap(df.describe(),linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.draw()
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\utils.py:660: UserWarning: Glyph 9 (	) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# <AxesSubplot:>
# C:\Users\lenovo\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
 df.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# Age                                                              0.046169
# City                                                             0.080912
# 4 What is the Pin Code of where you shop online...              -0.260365
# Duration                                                        -0.057096
# ...                                                                   ...
# Longer delivery period                                           0.060838
# Change in website/Application design                            -0.164818
# Frequent disruption when moving from one page t...              -0.256638
# Efficient Website                                                0.055663
# Recommendation                                                  -0.003372
#
#                                                          Age      City  \
# ...

# %%
corr_mat=df.corr()
plt.figure(figsize=(80,80))
sns.heatmap(corr_mat,annot=True)
plt.title("Correlation Matrix")
plt.savefig('correlation_matrix.jpg')
plt.show()
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.draw()
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\utils.py:660: UserWarning: Glyph 9 (	) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_31328\679646209.py:5: UserWarning: Glyph 9 (	) missing from current font.
#   plt.savefig('correlation_matrix.jpg')
# C:\Users\lenovo\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
type(corr_mat)
# Out:
# pandas.core.frame.DataFrame

# %%
corr_mat=df.corr()
corr_mat["Purchase Times"].sort_values(ascending=False)
# Out:
# Purchase Times                                                                                                                                                    1.000000
# Age                                                                                                                                                               0.309575
# 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                       0.215928
# City                                                                                                                                                              0.173871
# roles                                                                                                                                                             0.167532
# ...

# %%
plt.figure(figsize=(22,7))
df.corr()['Purchase Times'].sort_values(ascending=False).drop(['Purchase Times']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
# Out:
# Text(0.5, 0, 'Feature')
# C:\Users\lenovo\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Spliting the independent and target variables in x and y before removing skewness

# %%
x=df.drop("Purchase Times",axis=1)
y=df["Purchase Times"]

# %%
x
# Out:
#      1Gender of respondent  Age  City  \
# 0                      1.0  1.0   2.0
# 1                      0.0  0.0   2.0
# 2                      0.0  0.0   4.0
# 3                      1.0  0.0   6.0
# 4                      0.0  0.0   0.0
# ..                     ...  ...   ...
# 264                    0.0  0.0  10.0
# 265                    0.0  1.0   3.0
# 266                    0.0  2.0   0.0
# 267                    0.0  4.0  10.0
# 268                    0.0  2.0   3.0
#
#      4 What is the Pin Code of where you shop online from?  Duration  \
# 0                                               110009           3.0
# 1                                               110030           3.0
# 2                                               201308           2.0
# 3                                               132001           2.0
# 4                                               530068           1.0
# ..                                                 ...           ...
# ...

# %%
y
# Out:
# 0      2.0
# 1      3.0
# 2      3.0
# 3      5.0
# 4      0.0
#       ...
# 264    5.0
# 265    2.0
# 266    5.0
# 267    5.0
# 268    2.0
# Name: Purchase Times, Length: 269, dtype: float64

# %%
# Checking Skewness
x.skew().sort_values(ascending=False)
# Out:
# 4 What is the Pin Code of where you shop online from?                                                                                                             1.748322
# 11 What browser do you run on your device to access the website?\t\t\t                                                                                            1.710244
# Wild variety of product on offer                                                                                                                                  1.186071
# 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)                                                        1.119422
# 27 Empathy (readiness to assist with queries) towards the customers                                                                                               1.105678
# ...

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())

# %%
type(x_new)
# Out:
# numpy.ndarray

# %%
x.columns
# Out:
# Index(['1Gender of respondent', 'Age', 'City',
#        '4 What is the Pin Code of where you shop online from?', 'Duration',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
#        '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ',
# ...

# %%
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x
# Out:
#      1Gender of respondent       Age      City  \
# 0                 1.434161 -0.068059 -0.695625
# 1                -0.697272 -1.323991 -0.695625
# 2                -0.697272 -1.323991  0.001211
# 3                 1.434161 -1.323991  0.572468
# 4                -0.697272 -1.323991 -1.692065
# ..                     ...       ...       ...
# 264              -0.697272 -1.323991  1.515552
# 265              -0.697272 -0.068059 -0.326067
# 266              -0.697272  0.717043 -1.692065
# 267              -0.697272  1.762698  1.515552
# 268              -0.697272  0.717043 -0.326067
#
#      4 What is the Pin Code of where you shop online from?  Duration  \
# 0                                                  0.0      0.563671
# 1                                                  0.0      0.563671
# 2                                                  0.0     -0.306124
# 3                                                  0.0     -0.306124
# ...

# %%
x.skew().sort_values(ascending=False)
# Out:
# 11 What browser do you run on your device to access the website?\t\t\t                                                                                            1.533776
# 1Gender of respondent                                                                                                                                             0.741028
# Best Deal                                                                                                                                                         0.310581
# Reason for abandonment                                                                                                                                            0.232073
# Patronizing                                                                                                                                                       0.191232
# ...

# %%
sk=x.skew()

# %%
sk
# Out:
# 1Gender of respondent                                       0.741028
# Age                                                        -0.024246
# City                                                       -0.132990
# 4 What is the Pin Code of where you shop online from?       0.000000
# Duration                                                   -0.192246
#                                                               ...
# Longer delivery period                                     -0.226723
# Change in website/Application design                       -0.002355
# Frequent disruption when moving from one page to another   -0.271126
# Efficient Website                                           0.018153
# Recommendation                                              0.006779
# Length: 70, dtype: float64

# %%
np.abs(3)
# Out:
# 3

# %%
np.abs(-3)
# Out:
# 3

# %%
sk[np.abs(sk)>0.5].all()
# Out:
# True

# %% [markdown]
# #mod
# |a|
# |-3|=-(-3)=3
# |3|=3

# %%
x.skew()[np.abs(x.skew())<0.25].all()
# Out:
# False

# %% [markdown]
# # Considering the outlier removal:

# %%
df.shape
# Out:
# (269, 71)

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([  4,  16,  20,  30,  35,  49,  79,  88,  95, 112, 116, 133, 142,
#         159, 162, 196, 207, 234, 237, 262], dtype=int64),
#  array([11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11,
#         11, 11, 11], dtype=int64))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                      1.0                  1.0
# 1                      0.0                  0.0
# 2                      0.0                  0.0
# 3                      1.0                  0.0
# 5                      0.0                  1.0
# ..                     ...                  ...
# 264                    0.0                  0.0
# 265                    0.0                  1.0
# 266                    0.0                  2.0
# 267                    0.0                  4.0
# 268                    0.0                  2.0
#
#      3 Which city do you shop online from?  \
# 0                                      2.0
# 1                                      2.0
# 2                                      4.0
# 3                                      6.0
# 5                                      9.0
# ..                                     ...
# 264                                   10.0
# ...

# %%
df_new_z.shape
# Out:
# (249, 71)

# %%
#Percentage Loss of Data

# %%
Data_Loss=((269-249)/269)*100

# %%
Data_Loss
# Out:
# 7.434944237918216

# %% [markdown]
# Training Process

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
x.shape
# Out:
# (269, 70)

# %%
y.shape
# Out:
# (269,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
x_train.shape
# Out:
# (180, 70)

# %%
y_train.shape
# Out:
# (180,)

# %%
x_test.shape
# Out:
# (89, 70)

# %%
y_test.shape
# Out:
# (89,)

# %%
from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
preddt=dt.predict(x_test)
print(accuracy_score(y_test,preddt))
print(confusion_matrix(y_test,preddt))
print(classification_report(y_test,preddt))
# Out:
# 0.8314606741573034
# [[ 5  0  0  0  0  2]
#  [ 0  4  0  1  0  0]
#  [ 0  0 17  0  0  2]
#  [ 0  1  1 11  0  1]
#  [ 0  0  0  0  4  0]
#  [ 0  0  5  1  1 33]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.71      0.83         7
#          1.0       0.80      0.80      0.80         5
#          2.0       0.74      0.89      0.81        19
#          3.0       0.85      0.79      0.81        14
#          4.0       0.80      1.00      0.89         4
#          5.0       0.87      0.82      0.85        40
#
#     accuracy                           0.83        89
#    macro avg       0.84      0.84      0.83        89
# weighted avg       0.84      0.83      0.83        89

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 0.8202247191011236
# [[ 5  0  2  0  0  0]
#  [ 0  4  0  1  0  0]
#  [ 0  0 15  1  0  3]
#  [ 0  0  1 12  0  1]
#  [ 0  0  0  0  4  0]
#  [ 1  0  2  1  3 33]]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.71      0.77         7
#          1.0       1.00      0.80      0.89         5
#          2.0       0.75      0.79      0.77        19
#          3.0       0.80      0.86      0.83        14
#          4.0       0.57      1.00      0.73         4
#          5.0       0.89      0.82      0.86        40
#
#     accuracy                           0.82        89
#    macro avg       0.81      0.83      0.81        89
# weighted avg       0.83      0.82      0.82        89

# %%
from sklearn.svm import SVC

svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.5168539325842697
# [[ 4  0  0  0  0  3]
#  [ 1  0  0  0  0  4]
#  [ 0  0  7  7  0  5]
#  [ 0  0  1  8  0  5]
#  [ 0  0  0  4  0  0]
#  [ 1  0  5  7  0 27]]
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.57      0.62         7
#          1.0       0.00      0.00      0.00         5
#          2.0       0.54      0.37      0.44        19
#          3.0       0.31      0.57      0.40        14
#          4.0       0.00      0.00      0.00         4
#          5.0       0.61      0.68      0.64        40
#
#     accuracy                           0.52        89
#    macro avg       0.35      0.36      0.35        89
# weighted avg       0.49      0.52      0.49        89
